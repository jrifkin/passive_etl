# %%
import savReaderWriter as spss
path = r"O:\MSI\PERSONAL FOLDERS\Files for Jake\Passive\Passive Panel\Data\Dimension+P3 data_06-May-2015.sav"

# %%
data = spss.SavReader(path,returnHeader=True)

# %%
dir(data)
# Out:
# ['__class__',
#  '__cmp__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__enter__',
#  '__exit__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_encodeFileName',
#  '_getMissingValue',
#  '_getMultRespDef',
#  '_getMultRespDefsEx',
#  '_get_array_slice',
#  '_isAutoRawMode',
#  '_items',
#  '_loadLibs',
#  '_setColWidth10',
#  '_setMissingValue',
#  '_setMultRespDefs',
#  '_splitformats',
#  'alignments',
#  'all',
#  'autoRawMode',
#  'bareformats',
#  'caseBuffer',
#  'caseWeightVar',
#  'close',
#  'closeSavFile',
#  'columnWidths',
#  'dataEntryInfo',
#  'dateVariables',
#  'decode',
#  'encode',
#  'encoding_and_locale_set',
#  'errcheck',
#  'fd',
#  'fh',
#  'fileAttributes',
#  'fileCodePage',
#  'fileCompression',
#  'fileEncoding',
#  'fileLabel',
#  'formatValues',
#  'formats',
#  'formats_',
#  'freeMemory',
#  'get',
#  'getCaseBuffer',
#  'getFileReport',
#  'getHeader',
#  'getSavFileInfo',
#  'getStruct',
#  'head',
#  'header',
#  'idVar',
#  'ioLocale',
#  'ioUtf8',
#  'ioUtf8_',
#  'isCompatibleEncoding',
#  'libc',
#  'loadLibrary',
#  'measureLevels',
#  'memoize',
#  'missingValues',
#  'missingValuesLowHigh',
#  'multRespDefs',
#  'myStruct',
#  'nCases',
#  'numVars',
#  'numberofCases',
#  'numberofVariables',
#  'openSavFile',
#  'printPctProgress',
#  'queryType7',
#  'rawMode',
#  'recodeSysmisTo',
#  'record',
#  'releaseInfo',
#  'returnHeader',
#  'savFileName',
#  'seekNextCase',
#  'selectVars',
#  'setLocale',
#  'shape',
#  'spss2strDate',
#  'spssVersion',
#  'spssio',
#  'sysmis',
#  'sysmis_',
#  'systemString',
#  'tail',
#  'textInfo',
#  'unpack_from',
#  'vNames',
#  'valueLabels',
#  'varAttributes',
#  'varLabels',
#  'varNames',
#  'varNamesTypes',
#  'varRoles',
#  'varSets',
#  'varTypes',
#  'varWids',
#  'verbose',
#  'wholeCaseIn',
#  'wholeCaseOut',
#  'wide2utf8']

# %%
vals = data.valueLabels

# %%
type(vals)
# Out:
# dict

# %%
from pandas import DataFrame
DataFrame(vals)
# Out:
#     APP_DOWNLOAD                    CARRIER  \
# 0            NaN                        NaN
# 1            Yes                   T-Mobile
# 2             No                    Verizon
# 3            NaN                       AT&T
# 4            NaN            Sprint / Nextel
# 5            NaN                  Clearwire
# 6            NaN                   MetroPCS
# 7            NaN                US Cellular
# 8            NaN              Leap Wireless
# 9            NaN                    C Spire
# 10           NaN                        ATN
# 11           NaN      No carrier: Wifi only
# 12           NaN  No carrier: Prepaid cards
# 13           NaN            Other (Specify)
# 14           NaN                        NaN
# 15           NaN                        NaN
# 16           NaN                        NaN
# 17           NaN                        NaN
# 18           NaN                        NaN
# 19           NaN                        NaN
# 20           NaN                        NaN
# 21           NaN                        NaN
# 22           NaN                        NaN
# 23           NaN                        NaN
# 24           NaN                        NaN
# 25           NaN                        NaN
# 26           NaN                        NaN
# 27           NaN                        NaN
# 28           NaN                        NaN
# 29           NaN                        NaN
# ..           ...                        ...
# 211          NaN                        NaN
# 212          NaN                        NaN
# 213          NaN                        NaN
# 214          NaN                        NaN
# 215          NaN                        NaN
# 216          NaN                        NaN
# 217          NaN                        NaN
# 218          NaN                        NaN
# 219          NaN                        NaN
# 220          NaN                        NaN
# 221          NaN                        NaN
# 222          NaN                        NaN
# 223          NaN                        NaN
# 224          NaN                        NaN
# 225          NaN                        NaN
# 226          NaN                        NaN
# 227          NaN                        NaN
# 228          NaN                        NaN
# 229          NaN                        NaN
# 230          NaN                        NaN
# 231          NaN                        NaN
# 232          NaN                        NaN
# 233          NaN                        NaN
# 234          NaN                        NaN
# 235          NaN                        NaN
# 236          NaN                        NaN
# 237          NaN                        NaN
# 238          NaN                        NaN
# 239          NaN                        NaN
# 240          NaN                        NaN
#
#                                             DATA_LIMIT  \
# 0                                                  NaN
# 1                Data limit of less than 1GB per month
# 2         Data limit of 1GB to less than 3GB per month
# 3    Data limit of 3GB or more per month, but not u...
# 4                                  Unlimited data plan
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
#
#                             DATA_PLAN  \
# 0                                 NaN
# 1                       Pay as you go
# 2    A contract with monthly payments
# 3             Other type of data plan
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ..                                ...
# 211                               NaN
# 212                               NaN
# 213                               NaN
# 214                               NaN
# 215                               NaN
# 216                               NaN
# 217                               NaN
# 218                               NaN
# 219                               NaN
# 220                               NaN
# 221                               NaN
# 222                               NaN
# 223                               NaN
# 224                               NaN
# 225                               NaN
# 226                               NaN
# 227                               NaN
# 228                               NaN
# 229                               NaN
# 230                               NaN
# 231                               NaN
# 232                               NaN
# 233                               NaN
# 234                               NaN
# 235                               NaN
# 236                               NaN
# 237                               NaN
# 238                               NaN
# 239                               NaN
# 240                               NaN
#
#                                            DEVICE_TYPE  \
# 0                                                  NaN
# 1                                                 iPad
# 2    Android tablet (such as a Samsung Galaxy, Nexu...
# 3                                       Windows tablet
# 4                                         Other tablet
# 5                                               iPhone
# 6    Android Phone (such as a Samsung Galaxy, Galax...
# 7                                        Windows Phone
# 8                                          Blackberry
# 9                             Other type of smartphone
# 10                                          A computer
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
#
#                                             EMPLOYMENT     IDType  \
# 0                                                  NaN        NaN
# 1    Employed Full Time (working 30 or more hours p...    real ID
# 2    Employed Part Time (working less than 30 hours...  client ID
# 3                          Laid-off / looking for work   panel ID
# 4                                  Stay-at-home parent    test ID
# 5               Volunteer Work (at least 1 day / week)        NaN
# 6                      Full Time Undergraduate Student        NaN
# 7                      Part-time Undergraduate Student        NaN
# 8              Full Time or Part Time Graduate Student        NaN
# 9                                              Retired        NaN
# 10                            Something else (Specify)        NaN
# 11                                                 NaN        NaN
# 12                                                 NaN        NaN
# 13                                                 NaN        NaN
# 14                                                 NaN        NaN
# 15                                                 NaN        NaN
# 16                                                 NaN        NaN
# 17                                                 NaN        NaN
# 18                                                 NaN        NaN
# 19                                                 NaN        NaN
# 20                                                 NaN        NaN
# 21                                                 NaN        NaN
# 22                                                 NaN        NaN
# 23                                                 NaN        NaN
# 24                                                 NaN        NaN
# 25                                                 NaN        NaN
# 26                                                 NaN        NaN
# 27                                                 NaN        NaN
# 28                                                 NaN        NaN
# 29                                                 NaN        NaN
# ..                                                 ...        ...
# 211                                                NaN        NaN
# 212                                                NaN        NaN
# 213                                                NaN        NaN
# 214                                                NaN        NaN
# 215                                                NaN        NaN
# 216                                                NaN        NaN
# 217                                                NaN        NaN
# 218                                                NaN        NaN
# 219                                                NaN        NaN
# 220                                                NaN        NaN
# 221                                                NaN        NaN
# 222                                                NaN        NaN
# 223                                                NaN        NaN
# 224                                                NaN        NaN
# 225                                                NaN        NaN
# 226                                                NaN        NaN
# 227                                                NaN        NaN
# 228                                                NaN        NaN
# 229                                                NaN        NaN
# 230                                                NaN        NaN
# 231                                                NaN        NaN
# 232                                                NaN        NaN
# 233                                                NaN        NaN
# 234                                                NaN        NaN
# 235                                                NaN        NaN
# 236                                                NaN        NaN
# 237                                                NaN        NaN
# 238                                                NaN        NaN
# 239                                                NaN        NaN
# 240                                                NaN        NaN
#
#     MRKGROUPCODE1 MRKGROUPCODE2 MRKGROUPCODE3     ...     PERSONAL_USE15  \
# 0              No            No            No     ...                 No
# 1             Yes           Yes           Yes     ...                Yes
# 2             NaN           NaN           NaN     ...                NaN
# 3             NaN           NaN           NaN     ...                NaN
# 4             NaN           NaN           NaN     ...                NaN
# 5             NaN           NaN           NaN     ...                NaN
# 6             NaN           NaN           NaN     ...                NaN
# 7             NaN           NaN           NaN     ...                NaN
# 8             NaN           NaN           NaN     ...                NaN
# 9             NaN           NaN           NaN     ...                NaN
# 10            NaN           NaN           NaN     ...                NaN
# 11            NaN           NaN           NaN     ...                NaN
# 12            NaN           NaN           NaN     ...                NaN
# 13            NaN           NaN           NaN     ...                NaN
# 14            NaN           NaN           NaN     ...                NaN
# 15            NaN           NaN           NaN     ...                NaN
# 16            NaN           NaN           NaN     ...                NaN
# 17            NaN           NaN           NaN     ...                NaN
# 18            NaN           NaN           NaN     ...                NaN
# 19            NaN           NaN           NaN     ...                NaN
# 20            NaN           NaN           NaN     ...                NaN
# 21            NaN           NaN           NaN     ...                NaN
# 22            NaN           NaN           NaN     ...                NaN
# 23            NaN           NaN           NaN     ...                NaN
# 24            NaN           NaN           NaN     ...                NaN
# 25            NaN           NaN           NaN     ...                NaN
# 26            NaN           NaN           NaN     ...                NaN
# 27            NaN           NaN           NaN     ...                NaN
# 28            NaN           NaN           NaN     ...                NaN
# 29            NaN           NaN           NaN     ...                NaN
# ..            ...           ...           ...     ...                ...
# 211           NaN           NaN           NaN     ...                NaN
# 212           NaN           NaN           NaN     ...                NaN
# 213           NaN           NaN           NaN     ...                NaN
# 214           NaN           NaN           NaN     ...                NaN
# 215           NaN           NaN           NaN     ...                NaN
# 216           NaN           NaN           NaN     ...                NaN
# 217           NaN           NaN           NaN     ...                NaN
# 218           NaN           NaN           NaN     ...                NaN
# 219           NaN           NaN           NaN     ...                NaN
# 220           NaN           NaN           NaN     ...                NaN
# 221           NaN           NaN           NaN     ...                NaN
# 222           NaN           NaN           NaN     ...                NaN
# 223           NaN           NaN           NaN     ...                NaN
# 224           NaN           NaN           NaN     ...                NaN
# 225           NaN           NaN           NaN     ...                NaN
# 226           NaN           NaN           NaN     ...                NaN
# 227           NaN           NaN           NaN     ...                NaN
# 228           NaN           NaN           NaN     ...                NaN
# 229           NaN           NaN           NaN     ...                NaN
# 230           NaN           NaN           NaN     ...                NaN
# 231           NaN           NaN           NaN     ...                NaN
# 232           NaN           NaN           NaN     ...                NaN
# 233           NaN           NaN           NaN     ...                NaN
# 234           NaN           NaN           NaN     ...                NaN
# 235           NaN           NaN           NaN     ...                NaN
# 236           NaN           NaN           NaN     ...                NaN
# 237           NaN           NaN           NaN     ...                NaN
# 238           NaN           NaN           NaN     ...                NaN
# 239           NaN           NaN           NaN     ...                NaN
# 240           NaN           NaN           NaN     ...                NaN
#
#     PERSONAL_USE16      Quota_DeviceType  \
# 0               No                   NaN
# 1              Yes                Tablet
# 2              NaN  Smartphone---Android
# 3              NaN      Smartphone---IOS
# 4              NaN                   NaN
# 5              NaN                   NaN
# 6              NaN                   NaN
# 7              NaN                   NaN
# 8              NaN                   NaN
# 9              NaN                   NaN
# 10             NaN                   NaN
# 11             NaN                   NaN
# 12             NaN                   NaN
# 13             NaN                   NaN
# 14             NaN                   NaN
# 15             NaN                   NaN
# 16             NaN                   NaN
# 17             NaN                   NaN
# 18             NaN                   NaN
# 19             NaN                   NaN
# 20             NaN                   NaN
# 21             NaN                   NaN
# 22             NaN                   NaN
# 23             NaN                   NaN
# 24             NaN                   NaN
# 25             NaN                   NaN
# 26             NaN                   NaN
# 27             NaN                   NaN
# 28             NaN                   NaN
# 29             NaN                   NaN
# ..             ...                   ...
# 211            NaN                   NaN
# 212            NaN                   NaN
# 213            NaN                   NaN
# 214            NaN                   NaN
# 215            NaN                   NaN
# 216            NaN                   NaN
# 217            NaN                   NaN
# 218            NaN                   NaN
# 219            NaN                   NaN
# 220            NaN                   NaN
# 221            NaN                   NaN
# 222            NaN                   NaN
# 223            NaN                   NaN
# 224            NaN                   NaN
# 225            NaN                   NaN
# 226            NaN                   NaN
# 227            NaN                   NaN
# 228            NaN                   NaN
# 229            NaN                   NaN
# 230            NaN                   NaN
# 231            NaN                   NaN
# 232            NaN                   NaN
# 233            NaN                   NaN
# 234            NaN                   NaN
# 235            NaN                   NaN
# 236            NaN                   NaN
# 237            NaN                   NaN
# 238            NaN                   NaN
# 239            NaN                   NaN
# 240            NaN                   NaN
#
#                                          ReturnCode SMARTPHONE_BRAND  \
# 0                                               NaN              NaN
# 1                                      Not returned            Apple
# 2                                         Abandoned       Blackberry
# 3                                        Fraudulent              HTC
# 4                               Relevant duplicates               LG
# 5                                 Screen-out Client         Motorola
# 6                                    Screen-out IIS            Nokia
# 7                                 Quota Full Client          Samsung
# 8                                    Quota Full IIS             Sony
# 9                                          Complete              ZTE
# 10                               Complete Overquota            Other
# 11                            Abandoned from Cortex       Don�t know
# 12                            ScreenOut from CORTEX              NaN
# 13                                          Excused              NaN
# 14               Abandoned NC before media question              NaN
# 15                            Abandoned NC for Day2              NaN
# 16                                Complete Day 1 NC              NaN
# 17                                Complete Day 2 NC              NaN
# 18                 Complete Recruitment ProductTest              NaN
# 19                      Complete Recall ProductTest              NaN
# 20                                            Error              NaN
# 21                                      Unsubscribe              NaN
# 22                                   Wrong Complete              NaN
# 23                                  Wrong Screenout              NaN
# 24                                  Wrong Quotafull              NaN
# 25                      Abandoned from Landing Page              NaN
# 26          Redirected, not returned initial sample              NaN
# 27   Redirected, client screened out initial sample              NaN
# 28      Redirected, IIS screened out initial sample              NaN
# 29     Redirected, client quota full initial sample              NaN
# ..                                              ...              ...
# 211                                             NaN              NaN
# 212                                             NaN              NaN
# 213                                             NaN              NaN
# 214                                             NaN              NaN
# 215                                             NaN              NaN
# 216                                             NaN              NaN
# 217                                             NaN              NaN
# 218                                             NaN              NaN
# 219                                             NaN              NaN
# 220                                             NaN              NaN
# 221                                             NaN              NaN
# 222                                             NaN              NaN
# 223                                             NaN              NaN
# 224                                             NaN              NaN
# 225                                             NaN              NaN
# 226                                             NaN              NaN
# 227                                             NaN              NaN
# 228                                             NaN              NaN
# 229                                             NaN              NaN
# 230                                             NaN              NaN
# 231                                             NaN              NaN
# 232                                             NaN              NaN
# 233                                             NaN              NaN
# 234                                             NaN              NaN
# 235                                             NaN              NaN
# 236                                             NaN              NaN
# 237                                             NaN              NaN
# 238                                             NaN              NaN
# 239                                             NaN              NaN
# 240                                             NaN              NaN
#
#                                    SMARTPHONE_MODEL  \
# 0                                               NaN
# 1                                  Samsung Illusion
# 2                             Samsung Galaxy Note 3
# 3                                 Samsung Galaxy S
# 4                                 Samsung Galaxy S3
# 5                                 Samsung Galaxy S4
# 6                                     Other Samsung
# 7                                        LG Optimus
# 8                                             LG G2
# 9                                          Other LG
# 10                                          HTC One
# 11                                      HTC One max
# 12                                          HTC Evo
# 13                                        Other HTC
# 14                                  Motorola Droid
# 15                                 Motorola Moto X
# 16                                    Sony Xperia Z
# 17                                       Other Sony
# 18                        iPhone 6 or iPhone 6 Plus
# 19   iPhone 5 (including 5S and all other versions)
# 20                                         iPhone 4
# 21                    Earlier version of the iPhone
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# ..                                              ...
# 211                                             NaN
# 212                                             NaN
# 213                                             NaN
# 214                                             NaN
# 215                                             NaN
# 216                                             NaN
# 217                                             NaN
# 218                                             NaN
# 219                                             NaN
# 220                                             NaN
# 221                                             NaN
# 222                                             NaN
# 223                                             NaN
# 224                                             NaN
# 225                                             NaN
# 226                                             NaN
# 227                                             NaN
# 228                                             NaN
# 229                                             NaN
# 230                                             NaN
# 231                                             NaN
# 232                                             NaN
# 233                                             NaN
# 234                                             NaN
# 235                                             NaN
# 236                                             NaN
# 237                                             NaN
# 238                                             NaN
# 239                                             NaN
# 240                                             NaN
#
#                               SupplierID    TARGETRESP resp_age resp_gender
# 0                                    NaN           NaN      NaN         NaN
# 1                           Ipsos IIS EU     allocated        1        Male
# 2                       Ipsos ISay Panel  re-allocated        2      Female
# 3                        Ipsos iSay N*C            NaN        3         NaN
# 4                                   42mr           NaN        4         NaN
# 5                                Advaith           NaN        5         NaN
# 6                                    AIP           NaN        6         NaN
# 7                             All Global           NaN        7         NaN
# 8                          Amry Research           NaN        8         NaN
# 9                     Authentic Response           NaN        9         NaN
# 10                                Axxiom           NaN       10         NaN
# 11                     Borderless Access           NaN       11         NaN
# 12                               CanView           NaN       12         NaN
# 13                                  Cint           NaN       13         NaN
# 14                   Clear Voice Surveys           NaN       14         NaN
# 15                                   CMI           NaN       15         NaN
# 16                             Cotterweb           NaN       16         NaN
# 17                       Daedalus Online           NaN       17         NaN
# 18                              Decipher           NaN       18         NaN
# 19                      Decision Analyst           NaN       19         NaN
# 20                               Delvina           NaN       20         NaN
# 21                                   DMS           NaN       21         NaN
# 22                              eCGlobal           NaN       22         NaN
# 23                                Elogia           NaN       23         NaN
# 24                               Embrain           NaN       24         NaN
# 25                                   EMI           NaN       25         NaN
# 26                             ePocrates           NaN       26         NaN
# 27                                   ERI           NaN       27         NaN
# 28                               ERI N*C           NaN       28         NaN
# 29                                eWorks           NaN       29         NaN
# ..                                   ...           ...      ...         ...
# 211                MyOnlinePanels Europe           NaN      NaN         NaN
# 212                  NarodniPanel Europe           NaN      NaN         NaN
# 213                      Netetude Europe           NaN      NaN         NaN
# 214                      Netquest Europe           NaN      NaN         NaN
# 215                       Norstat Europe           NaN      NaN         NaN
# 216                           NRC Europe           NaN      NaN         NaN
# 217                    OMI Russia Europe           NaN      NaN         NaN
# 218              Online Solutions Europe           NaN      NaN         NaN
# 219                    Panel Clix Europe           NaN      NaN         NaN
# 220                     Panelbase Europe           NaN      NaN         NaN
# 221                      Panelbiz Europe           NaN      NaN         NaN
# 222                    Panels LTD Europe           NaN      NaN         NaN
# 223          Panelservices Africa Europe           NaN      NaN         NaN
# 224                     Panelteam Europe           NaN      NaN         NaN
# 225                      Pigsback Europe           NaN      NaN         NaN
# 226                          PORI Europe           NaN      NaN         NaN
# 227                         Pulse Europe           NaN      NaN         NaN
# 228                  Pure Profile Europe           NaN      NaN         NaN
# 229                 Quick Rewards Europe           NaN      NaN         NaN
# 230                  Research Now Europe           NaN      NaN         NaN
# 231  Research Now Europe PeanutLab 10151           NaN      NaN         NaN
# 232                      Respondi Europe           NaN      NaN         NaN
# 233                         Romir Europe           NaN      NaN         NaN
# 234                           SSI Europe           NaN      NaN         NaN
# 235              Tiburon Research Europe           NaN      NaN         NaN
# 236                        Toluna Europe           NaN      NaN         NaN
# 237                         USamp Europe           NaN      NaN         NaN
# 238                     Userneeds Europe           NaN      NaN         NaN
# 239                     Webfrager Europe           NaN      NaN         NaN
# 240                       Other provider           NaN      NaN         NaN
#
# [241 rows x 36 columns]
